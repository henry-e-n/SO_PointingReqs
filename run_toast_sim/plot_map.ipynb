# %%
import numpy as np
from toast_mapmaker import plot_maps
import os

# %%
out_dir = "/shared_home/henachman/SO_PointingReqs/sim_outputs/toast_outputs/simple10arcmin"
plot_maps(
    root=os.path.join(out_dir, "mapmaker"),
    gnomres = 8.0,
    gnomrot=(0, -60),
    xsize = 200,
    range_I=(-0.01, 0.01),
    range_Q=(-0.0002, 0.0002),
    range_U=(-0.0002, 0.0002),
    max_hits=1000,
    truth=None,  # You can specify a truth map file here if available
)
