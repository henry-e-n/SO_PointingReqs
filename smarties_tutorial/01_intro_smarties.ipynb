# %%
import numpy as np
from pathlib import Path
import sys

# Finds the root directory by walking up to a known anchor file
root_dir = Path("01_intro_smarties.ipynb").resolve().parents[1] 
if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))

from path_management import HOME_DIR, REPO_DIR, SMARTIES_CLONE, SMARTIES_DIR
# Add the smarties directory to the system path

if SMARTIES_CLONE not in sys.path:
    sys.path.append(str(SMARTIES_CLONE))
print(sys.path)
# Out:
# ['/shared_home/henachman/SO_PointingReqs', '/shared_home/software/soconda_builds/soconda_20260210_0.2.3/lib/python312.zip', '/shared_home/software/soconda_builds/soconda_20260210_0.2.3/lib/python3.12', '/shared_home/software/soconda_builds/soconda_20260210_0.2.3/lib/python3.12/lib-dynload', '', '/shared_home/henachman/.local/soconda/20260210_0.2.3/lib/python3.12/site-packages', '/shared_home/software/soconda_builds/soconda_20260210_0.2.3/lib/python3.12/site-packages', '/shared_home/henachman/smarties']

# %%
from smarties.utils.tools import get_coupled_spin, get_row_mapmaking_matrix
from smarties.sky.cmb import create_CMB_spin_maps
from smarties.hn import Spin_maps, Spin_nm
from smarties.utils.tools import reweight_hmaps_by_hits
from smarties.utils.interpolation import perform_interpolation_scipy
from smarties.utils.resolution import (
    get_slice_1d_from_2d, 
    get_chunks_from_shape, 
    get_projector_map_resolution,
    get_chunks_final_map_from_downgraded_chunks
)
# Out:
# /shared_home/henachman/smarties/smarties/utils/tools.py:35: SyntaxWarning: invalid escape sequence '\i'
#   """
# /shared_home/henachman/smarties/smarties/sky/cmb.py:125: SyntaxWarning: invalid escape sequence '\T'
#   """
# /shared_home/henachman/smarties/smarties/systematics/ellipticity.py:444: SyntaxWarning: invalid escape sequence '\e'
#   """
# /shared_home/henachman/smarties/smarties/systematics/pointing.py:27: SyntaxWarning: invalid escape sequence '\e'
#   """
# /shared_home/henachman/smarties/smarties/systematics/pointing.py:144: SyntaxWarning: invalid escape sequence '\T'
#   """
