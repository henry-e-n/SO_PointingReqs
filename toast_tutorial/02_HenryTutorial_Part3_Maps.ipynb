# %% [markdown]
# # Henry's Tutorial for TOAST Part II
#
# Date: 10 September 2026
#
# ---
#
# This is Part III of Henry's TOAST tutorial which will cover a basic pipeline of simulated TOD to maps but this time using SOTODLIB (instead of the builtin TOAST map maker).
